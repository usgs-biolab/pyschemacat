# %% [markdown]
# Part of the crux of the problem here is reading the schema.org metadata. I'm familiar with the specification and have worked on some projects with it, but I wasn't quite sure how to go about reading schema.org embedded metadata from landing pages with the various ways the spec has morphed. I first put this in place for ScienceBase a long time ago, and their process for loading the landing pages has really not changed since. It is woefully out of date, and that's likely to be one of our challenges.
#
# After a little poking around, I found the extruct package that seems to be one of the most mature in the Python world for extracting from web pages the different ways that schema.org properties can be found. I immediately ran into an issue with exploring dynamic systems like ScienceBase and NOAA One Stop where the pages are rendered with a partial client-side Javascript process that writes contents. A simple use of requests to pull contents didn't work, so I had to re-learn about selenium. That introduces some dependencies on an instantiation of a web browser on whatever machine is running this and access to drivers, which is going to be a pain if we wanted to set up an eventual instantiation of this with something like AWS Lambda. But that's a problem for another day.
#
# In this notebook, I use selenium and extruct to check out a couple examples that we might explore in this work. I pull back their different implementations of schema.org and document a number of issues I found.

# %%
import extruct
from selenium import webdriver

from IPython.display import display

# %% [markdown]
# ScienceBase, NOAA One Stop, and Data.gov are all catalogs that I happen to know have done some type of work with schema.org metadata on their landing pages. They also have interesting data that fits our overall use case. The URLs here are the main things we would be pulling back with some type of higher level search filter to get stuff of interest. I chose examples that all do have some type of mappable interface and should provide those links to us in their metadata somehow. I also did test each of these with Google's Structured Data Testing Tool to see how it renders out the information.

# %%
example_site_sb = 'https://www.sciencebase.gov/catalog/item/5b030c7ae4b0da30c1c1d6de'
#example_site_datagov = 'https://catalog.data.gov/dataset/epa-facility-registry-service-frs-facility-interests-dataset'
example_site_datagov = 'https://catalog.data.gov/dataset/235df488-53e1-4ebb-8a49-37134635e6ab'
example_site_noaa = 'https://data.noaa.gov/onestop/collections/details/AWbwQso3mm6hJphmMBul'

# %% [markdown]
# This is one of the stickier issues in this process based on how 2 of the 3 examples dynamically render their landing pages. I tested this with the chromium driver loaded into the Python virtual environment I'm working with as well, but the calling maching still needs to have an actual browser loaded and able to run. If we want to run this in a serverless context, we will have to explore other means. For now, the Firefox approach I use here works fine for testing.

# %%
wd = webdriver.Firefox()

# %% [markdown]
# ## ScienceBase
# In this first example, I grab up our example ScienceBase item and pull out its schema.org metadata. Things are a bit rough and not very workable for our use case here just yet. Here are a few observations:
#
# * ScienceBase is using the very outmoded microdata approach to embedding the metadata. At the time we did the work, that really was kind of the only way to go, so it makes sense. At this point, however, it would be far more extensible to go with a JSON-LD structure.
# * The content here is okay for basic discovery purposes, reflecting the long ago time when we put this into the ScienceBase infrastructure. At that time (ca. 2012ish, I think), we were really just experimenting with how well this approach would aid in our search engine optimization pursuit. It did well enough at the time.
# * There is no distribution information at all in the current ScienceBase implementation, so we're basically dead in the water for our core requirement.
# * There is contact information, which is one of the elements we might use for organizing the logical catalog browse list, so it will be a matter of determining whether or not the content is there to work from.
#
# If we're going to make this successful with ScienceBase, we are going to need to either lean on the ScienceBase team to update their implementation or write some kind of temporary "proxy" code that would transform ScienceBase's custom Item schema to JSON-LD syntax and use that as the foundational input we would prefer to pull directly from their landing pages.

# %%
wd.get(example_site_sb)
data = extruct.extract(wd.page_source, base_url=example_site_sb, uniform=True)
display(data)
# Out:
# {'microdata': [{'@type': 'Dataset',
#    '@context': 'http://schema.org',
#    'datePublished': '2018-09-30',
#    'articleSection': 'Summary',
#    'articleBody': 'The USGS Protected Areas Database of the United States (PAD-US) is the nation\'s inventory of protected areas, including public land and voluntarily provided private protected areas, identified as an A-16 National Geospatial Data Asset in the Cadastre Theme (https://communities.geoplatform.gov/ngda-cadastre/). The PAD-US is an ongoing project with several published versions of a spatial database including areas dedicated to the preservation of biological diversity, and other natural (including extraction), recreational, or cultural uses, managed for these purposes through legal or other effective means. The database was originally designed to support biodiversity assessments; however, its scope expanded in recent years to include all public and nonprofit lands and waters. Most are public lands owned in fee; however, long-term easements, leases, agreements, Congressional (e.g. \'Wilderness Area\'), Executive (e.g. \'National Monument\'), and administrative designations (e.g. \'Area of Critical Environmental Concern\') documented in agency management plans are also included. The PAD-US strives to be a complete inventory of public land and other protected areas, compiling "best available" data provided by managing agencies and organizations. The PAD-US geodatabase maps and describes areas with over twenty-five attributes in nine feature classes to support data management, queries, web mapping services, and analyses. This PAD-US Version 2.0 dataset includes a variety of updates and changes from the previous Version 1.4 dataset. The following list summarizes major updates and changes: 1) Expanded database structure with new layers: the geodatabase feature class structure now includes nine feature classes separating fee owned lands, conservation (and other) easements, management designations overlapping fee lands, marine areas, proclamation boundaries and various \'Combined\' feature classes (e.g. \'Fee\' + \'Easement\' + \'Designation\' feature classes); 2) Major update of the Federal estate including data from 8 agencies, developed in collaboration with the Federal Geographic Data Committee (FGDC) Federal Lands Working Group (FLWG, https://communities.geoplatform.gov/ngda-govunits/federal-lands-workgroup/); 3) Major updates to 30 States and limited additions to 16 other States; 4) Integration of The Nature Conservancy\'s (TNC) Secured Lands geodatabase; 5) Integration of Ducks Unlimited\'s (DU) Conservation and Recreation Lands (CARL) database; 6) Integration of The Trust for Public Land\'s (TPL) Conservation Almanac database; 7) The Nature Conservancy (TNC) Lands database update: the national source of lands owned in fee or managed by TNC; 8) National Conservation Easement Database (NCED) update: complete update of non-sensitive (suitable for publication in the public domain) easements; 9) Complete National Marine Protected Areas (MPA) update: from the NOAA MPA Inventory, including conservation measure (\'GAP Status Code\', \'IUCN Category\') review by NOAA; 10) First integration of Bureau of Energy Ocean Management (BOEM) managed marine lands: BOEM submitted Outer Continental Shelf Area lands managed for natural resources (minerals, oil and gas), a significant and new addition to PAD-US; 11) Fee boundary overlap assessment: topology overlaps in the PAD-US 2.0 \'Fee\' feature class have been identified and are available for user and data-steward reference (See Logical_Consistency_Report Section). For more information regarding the PAD-US dataset please visit, https://usgs.gov/gapanalysis/PAD-US/. For more information about data aggregation please review the “Data Manual for PAD-US” available at https://www.usgs.gov/core-science-systems/science-analytics-and-synthesis/gap/pad-us-data-manual.',
#    'image': 'PAD-US Map Viewer'}],
#  'json-ld': [],
#  'opengraph': [],
#  'microformat': [],
#  'rdfa': [{'@id': '_:N2e0894609b134621b3678b99fda4964f',
#    '@type': ['http://schema.org/Person'],
#    'http://schema.org/email': [{'@value': 'LisajJohnson@boisestate.edu'}],
#    'http://schema.org/faxNumber': [{'@value': '2084264370'}],
#    'http://schema.org/jobTitle': [{'@value': 'Protected Areas Database of the United States Coordinator'}],
#    'http://schema.org/name': [{'@value': 'Lisa Johnson'}],
#    'http://schema.org/telephone': [{'@value': '2088743102'}]},
#   {'@id': '_:Ndb4eab057a354301b17bdf2462a17e5b',
#    '@type': ['http://schema.org/PostalAddress'],
#    'http://schema.org/addressCountry': [{'@value': 'United States'}],
#    'http://schema.org/addressLocality': [{'@value': 'Boise'}],
#    'http://schema.org/addressRegion': [{'@value': 'Idaho'}],
#    'http://schema.org/streetAddress': [{'@value': '1910 University Drive'}]},
#   {'@id': '_:Nb481259c4fc14b5d82b1b90bffcbd55e',
#    '@type': ['http://schema.org/PostalAddress']},
#   {'@id': 'https://www.sciencebase.gov/catalog/item/5b030c7ae4b0da30c1c1d6de',
#    'http://www.w3.org/ns/rdfa#usesVocabulary': [{'@id': 'http://schema.org/'}]},
#   {'@id': '_:Ncd8f80d123c446a19d3f217feaa3413a',
#    '@type': ['http://schema.org/PostalAddress'],
#    'http://schema.org/addressCountry': [{'@value': 'United States'}],
#    'http://schema.org/addressLocality': [{'@value': 'Boise'}],
#    'http://schema.org/addressRegion': [{'@value': 'Idaho'}],
#    'http://schema.org/streetAddress': [{'@value': '1910 University Drive'}]},
#   {'@id': '_:N58c242ded2d24978a0633203b8a255ef',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menu'}]},
#   {'@id': '_:N03f322967c9843db99e3209fd354e2f2',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:N069a93f7c7c5458f9ea80e1b7282cf96',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:N18a33c7fee0d47548b5f118da85238e7',
#    '@type': ['http://schema.org/PostalAddress'],
#    'http://schema.org/addressCountry': [{'@value': 'USA'}],
#    'http://schema.org/addressLocality': [{'@value': 'Denver'}],
#    'http://schema.org/addressRegion': [{'@value': 'Colorado'}],
#    'http://schema.org/streetAddress': [{'@value': 'Denver Federal Center,'}]},
#   {'@id': '_:N383168ffa08c4d1181fa1cc75da082c3',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menu'}]},
#   {'@id': '_:Nc53d5383c055418ca7dbcc9d61664d5f',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:Nc3f8cecd162a430cb8779ba2d99d774a',
#    '@type': ['http://schema.org/Organization'],
#    'http://schema.org/name': [{'@value': 'U.S. Geological Survey'}]},
#   {'@id': '_:N267659733f244f81afb757989d04d6a7',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menu'}]},
#   {'@id': '_:N7ccb9d05d51947479ea6a6c3d83f66bb',
#    '@type': ['http://schema.org/Organization'],
#    'http://schema.org/name': [{'@value': 'Science Analytics and Synthesis'}]},
#   {'@id': '_:N778027e12e82460c9abedc2506ea5382',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:N274d90e9287d483ab224cf8f728c0f12',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#navigation'}]},
#   {'@id': '_:N6a11dde39f6745c8a9b102279bf680e4',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:N331ccefaff0e431c9645136de454e66b',
#    '@type': ['http://schema.org/Organization'],
#    'http://schema.org/name': [{'@value': 'Core Science Systems'}]},
#   {'@id': '_:N4446027b8a6e4625b9e9e2a26f81fb77',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:N85814035d0f648498efacbe2c56076ba',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': 'https://www.sciencebase.gov/catalog/item/5b030c7ae4b0da30c1c1d6de#no-cookie-support-alert',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#alert'}]},
#   {'@id': '_:Nd92aad04a5b64113a405e55c51067895',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#alert'}]},
#   {'@id': '_:Ne72525cce04344829a1a4141ce6c2369',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#log'}]},
#   {'@id': '_:N18243b9054314ec793565260da298c6f',
#    '@type': ['http://schema.org/Person'],
#    'http://schema.org/email': [{'@value': 'jpmagee@usgs.gov'}],
#    'http://schema.org/faxNumber': [{'@value': '5756461281'}],
#    'http://schema.org/jobTitle': [{'@value': 'Technical Information Specialist (Biology)'}],
#    'http://schema.org/name': [{'@value': 'Julie S Prior-Magee'}],
#    'http://schema.org/telephone': [{'@value': '5755571566'}]},
#   {'@id': '_:N9af706995a9a48c98040843e611f216b',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:N111c0d12e14f4a8d9031fc8a230536d0',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:Nf15f6e4dfea94bbeb3cd295d355a7a59',
#    '@type': ['http://schema.org/Organization'],
#    'http://schema.org/email': [{'@value': 'sciencebase@usgs.gov'}],
#    'http://schema.org/name': [{'@value': 'U.S. Geological Survey - ScienceBase'}],
#    'http://schema.org/telephone': [{'@value': '1-888- 275-8747'}]},
#   {'@id': '_:N5b32b1b149294265bd0babaeada615fd',
#    '@type': ['http://schema.org/Person'],
#    'http://schema.org/email': [{'@value': 'masoncroft@boisestate.edu'}],
#    'http://schema.org/jobTitle': [{'@value': 'Protected Areas Database of the United States Database Manager'}],
#    'http://schema.org/name': [{'@value': 'Mason Croft'}],
#    'http://schema.org/telephone': [{'@value': '2083018288'}]},
#   {'@id': '_:N0a4b4c56db80448fbc5ef67d908cbcb7',
#    '@type': ['http://schema.org/PostalAddress'],
#    'http://schema.org/addressCountry': [{'@value': 'USA'}],
#    'http://schema.org/addressLocality': [{'@value': 'Rodeo'}],
#    'http://schema.org/addressRegion': [{'@value': 'NM'}],
#    'http://schema.org/streetAddress': [{'@value': 'P.O. Box 162'}]},
#   {'@id': '_:N85bd6663af14498091d62c370f251b12',
#    '@type': ['http://schema.org/PostalAddress']},
#   {'@id': '_:N7cb1854ea5bd459ca1f1519d3fa309e3',
#    '@type': ['http://schema.org/PostalAddress']}]}

# %% [markdown]
# ## NOAA One Stop
# I had heard the NOAA guys at ESIP talking about their work with schema.org on landing pages for the NOAA One Stop search platform, so I thought this might be a good time to see what they were up to. There is quite a bit more structured content in the NOAA system that we might be able to exploit. Here are a few initial observations:
#
# * The identifiers and sameAs information here that will let us understand the relationships between NOAA DOIs and these landing pages that we might need depending on how we run our high level searches. (Note: I've not been able to track down a CSW interface for NOAA One Stop yet.)
# * The distribution information is pretty extensive and seems to include everything in the other forms of metadata. As expected, it's going to be pretty difficult to figure out what we might be able to include as a route to some type of OGC service or something otherwise mappable. Everything is of type DataDownload (still a moving target in the spec), and disambiguatingDescription is not helpful as implemented. We might look for key words in the descriptions, but this is an interesting example with "Dynamic GIS" on the one hand but "mapping application" on the other in one case. That link goes to a web mapper. The one service here that we could tease out with pattern recognition on the url is unfortunately down and out at the moment, which points to a need for making a decision on how to dig deeper on the links. The encodingFormat list here might also be useful as a filter, depending on how NOAA's convention works out on the values.
# * NOAA's keywords implementation is kind of interesting here with an embedded hierarchy in string format that we might experiment with for constructing our browse list.

# %%
wd.get(example_site_noaa)
data = extruct.extract(wd.page_source, base_url=example_site_noaa, uniform=True)
display(data)
# Out:
# {'microdata': [],
#  'json-ld': [{'@context': 'http://schema.org',
#    '@type': 'Dataset',
#    'name': 'U.S. Hourly Climate Normals (1981-2010)',
#    'alternateName': 'gov.noaa.ncdc:C00824',
#    'description': 'The U.S. Hourly Climate Normals for 1981 to 2010 are 30-year averages of meteorological parameters for thousands of U.S. stations located across the 50 states, as well as U.S. territories, commonwealths, the Compact of Free Association nations, and one station inCanada. NOAA Climate Normals are a large suite of data products that provide users with many tools to understand typical climate conditions for thousands of locations across the United States. As many NWS stations as possible are used, including those from the NWS Cooperative Observer Program (COOP) Network as well as some additional stations that have a Weather Bureau Army-Navy (WBAN) station identification number, including stations from the Climate Reference Network (CRN). The comprehensive U.S. Climate Normals dataset includes various derived products including daily air temperature normals (including maximum and minimum temperature normal, heating and cooling degree day normal, and others), precipitation normals (including snowfall and snow depth, percentiles, frequencies and other), and hourly normals (all normal derived from hourly data including temperature, dew point, heat index, wind chill, wind, cloudiness, heating and cooling degree hours, pressure normals). Users can access the data either by product or by station. Included in the dataset is extensive documentation to describe station metadata, filename descriptions, and methodology of producing the data. All data utilized in the computation of the 1981-2010 Climate Normals were taken from the ISD Lite (a subset of derived Integrated Surface Data), the Global Historical Climatology Network-Daily dataset, and standardized monthly temperature data (COOP). These source datasets (including intermediate datasets used in the computation of products) are also archived at the NOAA NCDC.',
#    'identifier': [{'value': 'AWbwQso3mm6hJphmMBul',
#      'propertyID': 'OneStop UUID',
#      '@type': 'PropertyValue'},
#     {'value': 'gov.noaa.ncdc:C00824',
#      'propertyID': 'NCEI Dataset Identifier',
#      '@type': 'PropertyValue'},
#     {'value': 'doi:10.7289/V5PN93JP',
#      'propertyID': 'Digital Object Identifier (DOI)',
#      '@type': 'PropertyValue'}],
#    'url': 'https://data.noaa.gov/onestop/collections/details/AWbwQso3mm6hJphmMBul',
#    'sameAs': ['https://doi.org/doi:10.7289/V5PN93JP',
#     'https://data.nodc.noaa.gov/cgi-bin/iso?id=gov.noaa.ncdc:C00824'],
#    'image': {'@type': 'ImageObject',
#     'url': 'https://www1.ncdc.noaa.gov/pub/data/metadata/images/1981-2010_ClimateNormals.jpg',
#     'contentUrl': 'https://www1.ncdc.noaa.gov/pub/data/metadata/images/1981-2010_ClimateNormals.jpg',
#     'caption': 'Preview graphic'},
#    'temporalCoverage': '1981-01-01T00:00:00.000Z/2010-12-31T00:00:00.000Z',
#    'spatialCoverage': [{'@type': 'Place',
#      'name': 'geographic bounding box',
#      'geo': {'@type': 'GeoShape',
#       'description': 'minY,minX maxY,maxX',
#       'box': '15,172 72,-65'}},
#     {'@type': 'Place', 'name': 'Puerto Rico'},
#     {'@type': 'Place',
#      'name': 'Continent > North America > United States Of America'},
#     {'@type': 'Place', 'name': 'Virgin Islands'},
#     {'@type': 'Place', 'name': 'Vertical Location > Land Surface'}],
#    'distribution': [{'@type': 'DataDownload',
#      'url': 'https://www.ncei.noaa.gov',
#      'description': 'NCEI home page with information, data access and contact information.',
#      'disambiguatingDescription': 'information (HTTPS)',
#      'name': 'NOAA National Centers for Environmental Information (NCEI)',
#      'encodingFormat': 'HTTPS'},
#     {'@type': 'DataDownload',
#      'url': 'https://data.nodc.noaa.gov/cgi-bin/iso?id=gov.noaa.ncdc:C00824',
#      'description': 'Hourly climate normals are computed for the 30 year period from 1981 to 2010 for U.S. stations (usually airports). Values include temperature, dew point temperature, sea level pressure, wind direction and speed, and other climate probabilities and statistics.',
#      'disambiguatingDescription': 'information (HTTPS)',
#      'name': 'Normals Hourly Description',
#      'encodingFormat': 'HTTPS'},
#     {'@type': 'DataDownload',
#      'url': 'ftp://ftp.ncdc.noaa.gov/pub/data/normals/1981-2010/',
#      'description': 'Dataset files available for download via FTP.',
#      'disambiguatingDescription': 'download (HTTP)',
#      'name': 'Climate Normals FTP Server'},
#     {'@type': 'DataDownload',
#      'url': 'https://www.ncdc.noaa.gov/cdo-web/search?datasetid=NORMAL_HLY',
#      'description': 'Search for the dataset via a text-based interface.',
#      'disambiguatingDescription': 'search (HTTPS)',
#      'name': 'NCEI Climate Data Online Data Search',
#      'encodingFormat': 'HTTPS'},
#     {'@type': 'DataDownload',
#      'url': 'https://gis.ncdc.noaa.gov/maps/ncei/normals&layers=1',
#      'description': 'Dynamic GIS mapping application to locate stations and data for selected layers.',
#      'disambiguatingDescription': 'search (HTTPS)',
#      'name': 'NCEI Climate Data Online Map Server',
#      'encodingFormat': 'HTTPS'},
#     {'@type': 'DataDownload',
#      'url': 'https://gis.ncdc.noaa.gov/arcgis/rest/services/cdo/normals/MapServer',
#      'description': 'ArcGIS Server REST API for the dataset.',
#      'disambiguatingDescription': 'download (HTTPS)',
#      'name': 'NCEI ArcGIS REST Services Directory',
#      'encodingFormat': 'HTTPS'},
#     {'@type': 'DataDownload',
#      'url': 'https://gis.ncdc.noaa.gov/kml/normal_hly.kmz',
#      'description': 'Direct download link for KMZ file.',
#      'disambiguatingDescription': 'download (HTTPS)',
#      'name': 'KMZ file for dataset',
#      'encodingFormat': 'HTTPS'},
#     {'@type': 'DataDownload',
#      'url': 'https://www1.ncdc.noaa.gov/pub/data/cdo/documentation/NORMAL_HLY_documentation.pdf',
#      'description': 'Documentation of the dataset including a data description, format layout and definitions.',
#      'disambiguatingDescription': 'information (HTTPS)',
#      'name': 'NCEI Dataset Documentation',
#      'encodingFormat': 'HTTPS'},
#     {'@type': 'DataDownload',
#      'url': 'https://www1.ncdc.noaa.gov/pub/data/cdo/samples/NORMAL_HLY_sample_csv.csv',
#      'description': 'This sample data file shows how the data are formatted in CSV and is for example purposes only.',
#      'disambiguatingDescription': 'download (HTTPS)',
#      'name': 'Hourly Climate Normals CSV Sample',
#      'encodingFormat': 'HTTPS'},
#     {'@type': 'DataDownload',
#      'url': 'https://www1.ncdc.noaa.gov/pub/data/cdo/samples/NORMAL_HLY_sample_ascii.dat',
#      'description': 'This sample data file shows how the data are formatted in fixed-length ASCII text and is for example purposes only.',
#      'disambiguatingDescription': 'download (HTTPS)',
#      'name': 'Hourly Climate Normals fixed-length ASCII Sample',
#      'encodingFormat': 'HTTPS'},
#     {'@type': 'DataDownload',
#      'url': 'https://www1.ncdc.noaa.gov/pub/data/normals/1981-2010/readme.txt',
#      'description': 'README describing the 1981-2010 Climate Normals.',
#      'disambiguatingDescription': 'information (HTTPS)',
#      'name': 'README for Climate Normals',
#      'encodingFormat': 'HTTPS'},
#     {'@type': 'DataDownload',
#      'url': 'https://www1.ncdc.noaa.gov/pub/data/normals/1981-2010/status.txt',
#      'description': 'Status of the 1981-2010 Climate Normals.',
#      'disambiguatingDescription': 'information (HTTPS)',
#      'name': 'STATUS document for the 1981-2010 Climate Normals',
#      'encodingFormat': 'HTTPS'}],
#    'keywords': ['Atmosphere > Atmospheric Temperature > Surface Temperature > Maximum/Minimum Temperature',
#     'Atmosphere > Atmospheric Temperature > Surface Temperature',
#     'Atmosphere > Atmospheric Temperature > Temperature Anomalies',
#     'Atmosphere > Precipitation > Precipitation Amount',
#     'Atmosphere > Precipitation > Precipitation Anomalies',
#     'Atmosphere > Precipitation > Liquid Precipitation > Rain',
#     'Atmosphere > Atmospheric Temperature > Degree Days'],
#    'encodingFormat': ['CSV',
#     'TSV',
#     'FIXED-LENGTH ASCII TEXT',
#     'ARCGIS',
#     'KMZ',
#     'PDF']}],
#  'opengraph': [{'og:image:height': '400',
#    'og:image:width': '800',
#    'og:image': '//www1.ncdc.noaa.gov/pub/data/metadata/images/1981-2010_ClimateNormals.jpg',
#    'og:site_name': 'National Oceanic and Atmospheric Administration',
#    'og:description': 'The U.S. Hourly Climate Normals for 1981 to 2010 are 30-year averages of meteorological parameters for thousands of U.S. stations located across the 50 states, as well as U.S. territories, commonwealths, the Compact of Free Association nations, and one station inCanada. NOAA Climate Normals are a large suite of data products that provide users with many tools to understand typical climate conditions for thousands of locations across the United States. As many NWS stations as possible are used, including those from the NWS Cooperative Observer Program (COOP) Network as well as some additional stations that have a Weather Bureau Army-Navy (WBAN) station identification number, including stations from the Climate Reference Network (CRN). The comprehensive U.S. Climate Normals dataset includes various derived products including daily air temperature normals (including maximum and minimum temperature normal, heating and cooling degree day normal, and others), precipitation normals (including snowfall and snow depth, percentiles, frequencies and other), and hourly normals (all normal derived from hourly data including temperature, dew point, heat index, wind chill, wind, cloudiness, heating and cooling degree hours, pressure normals). Users can access the data either by product or by station. Included in the dataset is extensive documentation to describe station metadata, filename descriptions, and methodology of producing the data. All data utilized in the computation of the 1981-2010 Climate Normals were taken from the ISD Lite (a subset of derived Integrated Surface Data), the Global Historical Climatology Network-Daily dataset, and standardized monthly temperature data (COOP). These source datasets (including intermediate datasets used in the computation of products) are also archived at the NOAA NCDC.',
#    'og:title': 'U S Hourly Climate Normals ... on NOAA OneStop',
#    'og:url': 'https://data.noaa.gov/onestop/collections/details/AWbwQso3mm6hJphmMBul',
#    '@type': 'website',
#    '@context': {'og': 'http://ogp.me/ns#'}}],
#  'microformat': [],
#  'rdfa': [{'@id': 'https://data.noaa.gov/onestop/collections/details/AWbwQso3mm6hJphmMBul#details-tablist',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#tablist'}]},
#   {'@id': '_:N3728b20cd02348bb9503816174d26f5a',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#contentInfo'}]},
#   {'@id': '_:N294c7f8078e54d84a75465c4d17ba28e',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:N228a310a1c6545b4948de6b4f754cc7a',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#button'}]},
#   {'@id': '_:N272cd6be4bd643bba8e7b73152966569',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': 'https://data.noaa.gov/onestop/collections/details/AWbwQso3mm6hJphmMBul#no-tab-content',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#tabpanel'}]},
#   {'@id': '_:N13c7bcf540784474b8427669fb198300',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#button'}]},
#   {'@id': '_:N1f58f5456b394b5799e3a8ebd2627ab8',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:N551a4ea295b3482faa88b3cb5448037f',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:N15ee8658f78e4e4db56594f5e08e1db8',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#button'}]},
#   {'@id': 'https://data.noaa.gov/onestop/collections/details/AWbwQso3mm6hJphmMBul',
#    'http://ogp.me/ns#description': [{'@value': 'The U.S. Hourly Climate Normals for 1981 to 2010 are 30-year averages of meteorological parameters for thousands of U.S. stations located across the 50 states, as well as U.S. territories, commonwealths, the Compact of Free Association nations, and one station inCanada. NOAA Climate Normals are a large suite of data products that provide users with many tools to understand typical climate conditions for thousands of locations across the United States. As many NWS stations as possible are used, including those from the NWS Cooperative Observer Program (COOP) Network as well as some additional stations that have a Weather Bureau Army-Navy (WBAN) station identification number, including stations from the Climate Reference Network (CRN). The comprehensive U.S. Climate Normals dataset includes various derived products including daily air temperature normals (including maximum and minimum temperature normal, heating and cooling degree day normal, and others), precipitation normals (including snowfall and snow depth, percentiles, frequencies and other), and hourly normals (all normal derived from hourly data including temperature, dew point, heat index, wind chill, wind, cloudiness, heating and cooling degree hours, pressure normals). Users can access the data either by product or by station. Included in the dataset is extensive documentation to describe station metadata, filename descriptions, and methodology of producing the data. All data utilized in the computation of the 1981-2010 Climate Normals were taken from the ISD Lite (a subset of derived Integrated Surface Data), the Global Historical Climatology Network-Daily dataset, and standardized monthly temperature data (COOP). These source datasets (including intermediate datasets used in the computation of products) are also archived at the NOAA NCDC.'}],
#    'http://ogp.me/ns#image': [{'@value': '//www1.ncdc.noaa.gov/pub/data/metadata/images/1981-2010_ClimateNormals.jpg'}],
#    'http://ogp.me/ns#image:height': [{'@value': '400'}],
#    'http://ogp.me/ns#image:width': [{'@value': '800'}],
#    'http://ogp.me/ns#site_name': [{'@value': 'National Oceanic and Atmospheric Administration'}],
#    'http://ogp.me/ns#title': [{'@value': 'U S Hourly Climate Normals ... on NOAA OneStop'}],
#    'http://ogp.me/ns#type': [{'@value': 'website'}],
#    'http://ogp.me/ns#url': [{'@value': 'https://data.noaa.gov/onestop/collections/details/AWbwQso3mm6hJphmMBul'}]},
#   {'@id': '_:N6e68f6f46e404408afed32fe7007248a',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:N0e1860e1690d4aae87f4b0771f25c212',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:Nd70a129bf67c4cb1bcbaa16f43a1e756',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:N13603103ebb84e688ed72a98455939b0',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:N42cb15db7a5d45548db635c8bc1b8160',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:Nce844745abef4ccfb374c6ee475eb8a4',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#alert'}]},
#   {'@id': '_:Nef155c82d6bb4cb1b586ef6551520559',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#search'}]},
#   {'@id': '_:Na48f9143ae4f433d820e33a1944dcae5',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': 'https://data.noaa.gov/onestop/collections/details/AWbwQso3mm6hJphmMBul#Overview-0-wrapper',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#tab'}]},
#   {'@id': '_:N201daad8338c4bf3a686e1d5735f0813',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#banner'}]},
#   {'@id': '_:N9aaf23fa4cb548a0a8281f60d0bc67c9',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:Ncf303bd9def84797b3d2370b81663d34',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#button'}]},
#   {'@id': '_:N62f9f64097f2492eb99f834e55b8d57f',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#   {'@id': '_:N707c949908194fa589a54ba274df9b03',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#button'}]}]}

# %% [markdown]
# ## Data.gov
# The Data.gov implementation of schema.org is interesting. I suspect that the team there has built some type of generalized schema.org metadata generation into their underlying CKAN implementation that may or may not be useful for our purposes.
#
# * The majority of the content here is made up of tags and keywords in a couple different forms. Those are such a hodgepodge of different concepts with no qualification or semantics, so they will be very difficult to use in meaningful ways.
# * The Data.gov folks have taken an interesting approach to distribution links. They seem to be now pointing every link at an intermediary page rendering in the Data.gov system itself where a link to something real may or may not be active. As it stands, the URLs in the actual point of metadata are not going to be usable for our purposes.\
# * One of the real challenges with Data.gov for broader use cases than ours is the issue of provenance back to source material from this much higher level aggregator. They could really use the sameAs concept here to help keep track of what these records are related to back in source systems from providing agencies.

# %%
wd.get(example_site_datagov)
data = extruct.extract(wd.page_source, base_url=example_site_datagov, uniform=True)
display(data)
# Out:
# {'microdata': [{'@type': 'Dataset',
#    '@context': 'http://schema.org',
#    'name': 'USGS US Topo Map Collection',
#    'dateModified': 'June 28, 2019',
#    'description': 'Layered GeoPDF 7.5 Minute Quadrangle Map. Layers of geospatial data include orthoimagery, roads, grids, geographic names, elevation contours, hydrography, and other selected map features. This map depicts geographic features on the surface of the earth. One intended purpose is to support emergency response at all levels of government. The geospatial data in this map are from selected National Map data holdings and other government sources.',
#    'distribution': [{'@type': 'DataDownload',
#      'contentUrl': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/64afef66-f652-4112-b37c-09e772647a94',
#      'description': 'Web Accessible Folder'},
#     {'@type': 'DataDownload',
#      'contentUrl': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/38271f4d-7d88-4ccb-b77d-9b83bc9e95c4',
#      'description': 'TNM US Topo Availability Web Map Services'},
#     {'@type': 'DataDownload',
#      'contentUrl': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/a2e5e8ba-3e8a-4ded-8861-7cc203f75af7',
#      'description': 'ScienceBase OGC-CSW interface for harvesting the collection'},
#     {'@type': 'DataDownload',
#      'contentUrl': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/d1e71e42-8203-4a2f-9a85-1b1d551ca464',
#      'description': 'ScienceBase OAI-PMH interface for harvesting the collection as CSDGM metadata'},
#     {'@type': 'DataDownload',
#      'contentUrl': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/320040fb-07aa-4a43-9fa9-af023620196e',
#      'description': 'ScienceBase-generated KML (Google Earth) interface to the entire collection'},
#     {'@type': 'DataDownload',
#      'contentUrl': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/b746491d-bf89-4d10-ba6a-5ba0794ca27e',
#      'description': 'ScienceBase-generated OGC-WMS interface to the entire collection'},
#     {'@type': 'DataDownload',
#      'contentUrl': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/4decd0cc-561d-4862-a0e0-620a12ddd5ce',
#      'description': 'ScienceBase-generated OGC-WFS interface to the entire collection'},
#     {'@type': 'DataDownload',
#      'contentUrl': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/32f1b136-2c17-40f0-93c0-7b9791b0e043',
#      'description': 'ScienceBase JSON interface to the entire collection'},
#     {'@type': 'DataDownload',
#      'contentUrl': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/e70ca3d0-9745-477b-b2a2-9182ddd7af4d',
#      'description': 'ScienceBase ATOM/OpenSearch interface to the entire collection'},
#     {'@type': 'DataDownload',
#      'contentUrl': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/d1e3a254-b323-4c0e-9f6c-17c849418256',
#      'description': 'ScienceBase CSV summary interface to the entire collection'},
#     {'@type': 'DataDownload',
#      'contentUrl': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/17995ebe-20d7-4d2c-8654-638f8ac1963d',
#      'description': 'ScienceBase interface to download attached files in the ScienceBase repository'},
#     {'@type': 'DataDownload',
#      'contentUrl': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/83097894-ffd6-4b94-acc8-7d4b1496821f',
#      'description': ''}],
#    'keywords': ['topographic',
#     'hydrography',
#     'public land survey ...',
#     'woodland',
#     'us',
#     'united states',
#     'geographic names',
#     'u.s. national grid',
#     'orthoimage',
#     'transportation',
#     'boundary',
#     'structures',
#     'contour'],
#    'publisher': {'@type': 'Organization',
#     'name': 'U.S. Geological Survey, National Geospatial Technical Operations Center (Point of Contact)'}},
#   {'value': 'https://catalog.data.gov/dataset?tags=topographic',
#    '@type': 'Text',
#    '@context': 'http://schema.org'},
#   {'value': 'https://catalog.data.gov/dataset?tags=hydrography',
#    '@type': 'Text',
#    '@context': 'http://schema.org'},
#   {'value': 'https://catalog.data.gov/dataset?tags=public+land+survey+system',
#    '@type': 'Text',
#    '@context': 'http://schema.org'},
#   {'value': 'https://catalog.data.gov/dataset?tags=woodland',
#    '@type': 'Text',
#    '@context': 'http://schema.org'},
#   {'value': 'https://catalog.data.gov/dataset?tags=us',
#    '@type': 'Text',
#    '@context': 'http://schema.org'},
#   {'value': 'https://catalog.data.gov/dataset?tags=united+states',
#    '@type': 'Text',
#    '@context': 'http://schema.org'},
#   {'value': 'https://catalog.data.gov/dataset?tags=geographic+names',
#    '@type': 'Text',
#    '@context': 'http://schema.org'},
#   {'value': 'https://catalog.data.gov/dataset?tags=u.s.+national+grid',
#    '@type': 'Text',
#    '@context': 'http://schema.org'},
#   {'value': 'https://catalog.data.gov/dataset?tags=orthoimage',
#    '@type': 'Text',
#    '@context': 'http://schema.org'},
#   {'value': 'https://catalog.data.gov/dataset?tags=transportation',
#    '@type': 'Text',
#    '@context': 'http://schema.org'},
#   {'value': 'https://catalog.data.gov/dataset?tags=boundary',
#    '@type': 'Text',
#    '@context': 'http://schema.org'},
#   {'value': 'https://catalog.data.gov/dataset?tags=structures',
#    '@type': 'Text',
#    '@context': 'http://schema.org'},
#   {'value': 'https://catalog.data.gov/dataset?tags=contour',
#    '@type': 'Text',
#    '@context': 'http://schema.org'}],
#  'json-ld': [],
#  'opengraph': [],
#  'microformat': [],
#  'rdfa': [{'@id': 'https://catalog.data.gov/dataset/235df488-53e1-4ebb-8a49-37134635e6ab',
#    'dct:issued': [{'@value': 'December 7, 2016'}],
#    'dct:modified': [{'@value': 'June 28, 2019'}],
#    'dct:publisher': [{'@value': 'U.S. Geological Survey, National Geospatial Technical Operations Center (Point of Contact)'}],
#    'http://purl.org/dc/terms/format': [{'@value': 'FGDC'},
#     {'@value': 'ISO-19139'}],
#    'http://purl.org/dc/terms/relation': [{'@id': '_:Nbf2af65313704663aa5b0b31513362df'}],
#    'http://purl.org/dc/terms/rights': [{'@id': 'http://www.usa.gov/publicdomain/label/1.0/'}],
#    'http://www.w3.org/1999/02/22-rdf-syntax-ns#value': [{'@value': '\n                    \n                      irregular\n                    \n                  '}],
#    'http://www.w3.org/2000/01/rdf-schema#label': [{'@value': 'Frequency Of Update'}]},
#   {'@id': '_:Nbf2af65313704663aa5b0b31513362df',
#    'http://www.w3.org/1999/02/22-rdf-syntax-ns#value': [{'@value': '\n                \n\n                \n                     geospatial\n                \n              '},
#     {'@value': '\n                \n\n                \n                     \n                \n              '},
#     {'@value': '\n                \n\n                \n                     true\n                \n              '},
#     {'@value': '\n                \n\n                \n                     -179.1666667\n                \n              '},
#     {'@value': '\n                \n\n                \n                     2009-01-01\n                \n              '},
#     {'@value': '\n                \n\n                \n                     Use Constraints: None. However, users should be aware that temporal changes may have occurred since this data set was collected and that some parts of this data may no longer represent actual surface conditions. Users should not use this data for critical applications without a full awareness of its limitations. Acknowledgment of the U.S. Geological Survey would be appreciated for products derived from these data., Access Constraints: None\n                \n              '},
#     {'@value': '\n                \n\n                \n                     Although these data have been processed successfully on a computer system at the U.S.\n      Geological Survey, no warranty expressed or implied is made regarding the accuracy or utility\n      of the data on any other system or for general or scientific purposes, nor shall the act of\n      distribution constitute any such warranty. This disclaimer applies both to individual use of\n      the data and aggregate use with other data. It is strongly recommended that these data are\n      directly acquired from a U.S. Geological Survey server, and not indirectly through other\n      sources which may have changed the data in some way. It is also strongly recommended that\n      careful attention be paid to the contents of the metadata file associated with these data. The\n      U.S. Geological Survey shall not be held liable for improper or incorrect use of the data\n      described and/or contained herein.\n                \n              '},
#     {'@value': '\n                \n\n                \n                     17.625\n                \n              '},
#     {'@value': '\n                \n\n                \n                     -65\n                \n              '},
#     {'@value': '\n                \n\n                \n                     71.5\n                \n              '},
#     {'@value': '\n                \n\n                \n                     USGS US Topo Maps\n                \n              '},
#     {'@value': '\n                \n\n                \n              '},
#     {'@value': '\n                \n\n                \n                     irregular\n                \n              '},
#     {'@value': '\n                \n\n                \n                     True\n                \n              '},
#     {'@value': '\n                \n\n                \n                     2013-01-01\n                \n              '},
#     {'@value': '\n                \n\n                \n                     completed\n                \n              '},
#     {'@value': '\n                \n\n                \n                     0a8d8786-db8f-42b5-95ad-3cf6cafa9f5b\n                \n              '},
#     {'@value': '\n                \n\n                \n                     81c18d73-802a-444b-8bf2-75ef33ed83d8\n                \n              '}],
#    'http://www.w3.org/2000/01/rdf-schema#label': [{'@value': 'Coupled Resource'},
#     {'@value': 'Spatial Data Service Type'},
#     {'@value': 'Metadata Language'},
#     {'@value': 'Guid'},
#     {'@value': 'Temporal Extent Begin'},
#     {'@value': 'Harvest Source Title'},
#     {'@value': 'Temporal Extent End'},
#     {'@value': 'Harvest Object Id'},
#     {'@value': 'Progress'},
#     {'@value': 'Bbox West Long'},
#     {'@value': 'Frequency Of Update'},
#     {'@value': 'Licence'},
#     {'@value': 'Spatial Harvester'},
#     {'@value': 'Access Constraints'},
#     {'@value': 'Metadata Type'},
#     {'@value': 'Bbox East Long'},
#     {'@value': 'Bbox North Lat'},
#     {'@value': 'Collection Metadata'},
#     {'@value': 'Bbox South Lat'},
#     {'@value': 'Spatial Reference System'},
#     {'@value': 'Harvest Source Id'}]},
#   {'@id': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/d1e71e42-8203-4a2f-9a85-1b1d551ca464',
#    'http://purl.org/dc/terms/format': [{'@value': 'OAI-PMH'}]},
#   {'@id': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/a2e5e8ba-3e8a-4ded-8861-7cc203f75af7',
#    'http://purl.org/dc/terms/format': [{'@value': 'csw'}]},
#   {'@id': '_:N26c5e83f126a42e88dc19e2b5781e9c3',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#search'}]},
#   {'@id': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/32f1b136-2c17-40f0-93c0-7b9791b0e043',
#    'http://purl.org/dc/terms/format': [{'@value': 'JSON'}]},
#   {'@id': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/4decd0cc-561d-4862-a0e0-620a12ddd5ce',
#    'http://purl.org/dc/terms/format': [{'@value': 'WMS'}]},
#   {'@id': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/b746491d-bf89-4d10-ba6a-5ba0794ca27e',
#    'http://purl.org/dc/terms/format': [{'@value': 'WMS'}]},
#   {'@id': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/e70ca3d0-9745-477b-b2a2-9182ddd7af4d',
#    'http://purl.org/dc/terms/format': [{'@value': 'ATOM'}]},
#   {'@id': '_:Nbe9b3f13a1734e2594b166bf6b59d761',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#navigation'}]},
#   {'@id': '_:Ne4fa895e48ba4c1b91b783e2769d8a79',
#    '@type': ['http://xmlns.com/foaf/0.1/Person'],
#    'http://xmlns.com/foaf/0.1/mbox': [{'@value': '\n             \n             \n              https://www.usgs.gov/ask/\t\n             \n             '}]},
#   {'@id': '_:Nf65ac314ef55468c8a9e997b4af8ad00',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#navigation'}]},
#   {'@id': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/d1e3a254-b323-4c0e-9f6c-17c849418256',
#    'http://purl.org/dc/terms/format': [{'@value': 'ATOM'}]},
#   {'@id': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/83097894-ffd6-4b94-acc8-7d4b1496821f',
#    'http://purl.org/dc/terms/format': [{'@value': ''}]},
#   {'@id': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/17995ebe-20d7-4d2c-8654-638f8ac1963d',
#    'http://purl.org/dc/terms/format': [{'@value': 'Download'}]},
#   {'@id': '_:N1a2002e44f174ac6bacc2f16531533e3',
#    'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#main'}]},
#   {'@id': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/64afef66-f652-4112-b37c-09e772647a94',
#    'http://purl.org/dc/terms/format': [{'@value': 'WAF'}]},
#   {'@id': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/320040fb-07aa-4a43-9fa9-af023620196e',
#    'http://purl.org/dc/terms/format': [{'@value': 'WMS'}]},
#   {'@id': 'https://catalog.data.gov/dataset/usgs-us-topo-map-collection/resource/38271f4d-7d88-4ccb-b77d-9b83bc9e95c4',
#    'http://purl.org/dc/terms/format': [{'@value': 'Esri REST'}]}]}
